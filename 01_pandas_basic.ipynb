# %% [markdown]
# <a href="https://colab.research.google.com/github/gimhanul/dataAnalysis/blob/master/01_pandas_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ---
#
# # **해결문제**
#
#
# 최근 50년간의 출생자수, 사망자수, 혼인건수를 분석하시오.
#
# ---

# %% [markdown]
# # **pandas**
#
#
# ---
#
#
# ## **파이썬에서 사용하는 데이터분석 라이브러리**
#  + 행과 열로 이루어진 데이터 객체를 만들어 다룰 수 있게 되며 보다 안정적으로 대용량의 데이터들을 처리하는데 매우 편리한 도구
#  + NumPy를 기반으로 구축되었으며 과학 컴퓨팅 환경 내에서 다른 많은 타사 라이브러리와 잘 통합되도록 설계
#  + 많은 기능을 가진 데이터 구조
#    - 다양한 방식으로 색인된 데이터를 다룰 수 있는 기능
#    - 시계열 데이터와 비시계열 데이터를 함께 다룰 수 있는 통합 자료 구조
#    - 누락된 데이터를 유연하게 처리할 수 있는 기능
#    - SQL 같은 일반 데이터베이스처럼 데이터를 합치고 관계연산을 수행하는 기능
#
# ### **pandas 자료 구조**
# * **Series**
#  + 1차원 자료구조
#  + index로 value를 구분하는 1차원 자료구조
#
# * **DataFrame**
#  + 2차원 자료구조
#  + DataFrame는 행과 열이 있는 테이블 데이터
#
#
#
# ---

# %%
#pandas 라이브러리 추가
import pandas as pd

# %% [markdown]
# ## **외부 데이터 가져오기**
# + csv 읽기
#  - 한글 파일명을 사용할 경우 : df = pd.read_csv(‘파일명‘, engine='python')
#  - 파일 내용 한글이 깨지는 경우 : df = pd.read_csv(‘파일명‘, engine='python', encoding='cp949')
# >
# ```
# df = pd.read_csv(‘파일명‘)
# ```
#
# + 엑셀 읽기
#  - 한글 파일명을 사용할 경우 : df = pd.read_excel(‘파일명‘)
# >
# ```
# df = pd.pd.read_excel(‘파일명‘)
# ```

# %% [markdown]
# &#9997; **Note: Colab에서 구글 드라이브 연동**
#
# ---
# * 구글 드라이브를 마운트
# >
# ```
# from google.colab import drive
# drive.mount('/content/gdrive')
# ```

# %%
#CSV 파일불러오기
df = pd.read_csv('/content/drive/MyDrive/datathon/class/data/인구분석_출생사망.csv', engine='python', encoding='cp949')

# %% [markdown]
# ## 데이터프레임(DataFrame) 살펴보기
# * 데이터프레임의 정보 : **df.info()**
#  - 데이터프레임에 대한 전반적인 정보
#  - 데이터프레임을 구성하는 행과 열의 크기, 컬럼명, 컬럼을 구성하는 값의 자료형 등을 출력
# + 데이터프레임의 크기 확인 : **df.shape 속성**
#  - (행, 열) 크기를 확인하기
#  - 행의 개수 : len(데이터프레임), len(.index), .shape[0]
#  - 열의 개수 : len(.column), .shape[1]
# + 데이터프레임의 원소의 총개수 : **df.size 속성**
# + 데이터프레임 개수 확인 :**df.count()**
#  - Null이 아닌 행의 개수 확인
#  - axis='columns' : Null이 아닌 열의 개수 확인

# %%
#데이터프레임의 크기 확인
print('데이터프레임 (행, 열) : ', df.shape)
print('데이터프레임 행 개수 len : ', len(df) )
print('데이터프레임 행 개수 len : ', len(df.index) )
print('데이터프레임 행 개수 shape : ', df.shape[0] )
print('데이터프레임 열 개수 len : ', len(df.columns) )
print('데이터프레임 열 개수 shape : ', df.shape[1] )
# Out:
# 데이터프레임 (행, 열) :  (51, 4)
# 데이터프레임 행 개수 len :  51
# 데이터프레임 행 개수 len :  51
# 데이터프레임 행 개수 shape :  51
# 데이터프레임 열 개수 len :  4
# 데이터프레임 열 개수 shape :  4

# %%
#데이터프레임 정보 확인 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   년도       51 non-null     int64
#  1   출생아수(명)  51 non-null     int64
#  2   사망자수(명)  51 non-null     int64
#  3   혼인건수(건)  51 non-null     int64
# dtypes: int64(4)
# memory usage: 1.7 KB

# %% [markdown]
# ## **데이터프레임(DataFrame) 기본 조회**
# * head(n) : 상위 n개 조회, n생략 시 5개 조회
# + tail(n) : 하위 n개 조회, n생략 시 5개 조회

# %%
 df.head(3)
 df.tail(4)
# Out:
#       년도  출생아수(명)  사망자수(명)  혼인건수(건)
# 47  2017   357771   285534   264455
# 48  2018   326822   298820   257622
# 49  2019   302676   295110   239159
# 50  2020   272337   304948   213502

# %% [markdown]
# ## 데이터프레임의 인덱스
#  + 열의 인덱스 : **df.colums**
#  + 행의 인덱스 : **df.index**
#  + **데이터프레임의 인덱스 변경**
#    - 열인덱스 명 변경 : df.column = [열명인덱스]
#    - 열항목 중 하나를 인덱스로 사용 : df.set_index(열명)
#    - 인덱스를 일반 데이터 열로 전환 : df.reset_index()

# %%
#행인덱스 확인
df.index #stop 포함 안 됨
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %%
#열인덱스 확인
df.columns
# Out:
# Index(['년도', '출생아수(명)', '사망자수(명)', '혼인건수(건)'], dtype='object')

# %% [markdown]
# &#9997; **Note: Python 리스트(list)**
#
# ---
# + 리스트(list)
#  - 리스트의 각 요소는 순서를 가지고 있음
#  - 대괄호([])로 작성되며 각 요소는 쉼표(,)로 구분
#  - 요소를 추가, 수정, 삭제 가능
#
# + 리스트 접근
#  - for ... in
#
# + 조건에 맞는 리스트 출력 추출
#   >
#   ```
#   [item for item in lt]
#   [item for item in lt if 조건식]
#   [item if 조건식 else 조건식 for item in lt]
#   ```

# %%
#열인덱스를 리스트로 만들기
lt = list(df.columns)
lt
# Out:
# ['년도', '출생아수(명)', '사망자수(명)', '혼인건수(건)']

# %%
#리스트 한줄로 항목 출력 
for item in lt:
   print(item)
# Out:
# 년도
# 출생아수(명)
# 사망자수(명)
# 혼인건수(건)

# %%
#리스트 한줄로 조건에 맞는 항목 출력 
[item for item in lt]
# Out:
# ['년도', '출생아수(명)', '사망자수(명)', '혼인건수(건)']

# %%
#리스트 한줄로 조건에 맞는 항목 출력 
[item for item in lt if item == '년도']
lt = [item if item == '년도' else item[:-3] for item in lt]

# %%
#데이터프레임 열명리스트 만들기 
df.columns = lt

# %%
#데이터프레임 열명 출력
df.columns
# Out:
# Index(['년도', '출생아수', '사망자수', '혼인건수'], dtype='object')

# %%
#데이터프레임 변경 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      51 non-null     int64
#  1   출생아수    51 non-null     int64
#  2   사망자수    51 non-null     int64
#  3   혼인건수    51 non-null     int64
# dtypes: int64(4)
# memory usage: 1.7 KB

# %%
#데이터프레임 행인덱스 변경
df = df.set_index('년도')

# %% [markdown]
# ## **데이터프레임(DataFrame)기초 통계 메소드**
# + mean() : 평균
# + max() : 최대
# + min() : 최소
# + std()  : 표준편차
# + 데이터의 컬럼별 요약: **df.describe()**
#   + 데이터의 컬럼별 요약 통계량
#   + mean(), max(), median()등 개별 함수를 사용하여 통계량을 계산가능
#   + 범주형 데이터 요약 : include='O'

# %%
#평균구하기
#데이터 프레임의 열 하나는 Series
df['사망자수'].mean()
df.mean()
# Out:
# 출생아수    635915.901961
# 사망자수    252651.823529
# 혼인건수    337232.784314
# dtype: float64

# %%
#통계 요약
df.describe()
# Out:
#                출생아수           사망자수           혼인건수
# count  5.100000e+01      51.000000      51.000000
# mean   6.359159e+05  252651.823529  337232.784314
# std    1.931547e+05   18212.010337   57762.431966
# min    2.723370e+05  210071.000000  213502.000000
# 25%    4.707180e+05  241943.000000  302665.500000
# 50%    6.400890e+05  246463.000000  329087.000000
# 75%    7.599415e+05  262423.000000  390252.500000
# max    1.024773e+06  304948.000000  434911.000000

# %% [markdown]
# ## **데이터프레임 추출하기**
# + 열자료 가져오기 : df[]
#  + 특정 열 가져오기 : df[열인덱스], df[열인덱스 리스트]
#  + 특정 행 가져오기 : df[시작행인덱스:종료행인덱스]
#
# + 인덱스명으로 특정 항목 가져오기 : df.loc[행인덱스, 열인덱스]
#   * 특정 열 가져오기 : df.loc[:, 열인덱스]
#   * 특정 행 가져오기 : df.loc[행인덱스, :]
#   * 특정 항목 가져오기 : df.loc[행인덱스, 열인덱스]
#
# + 인덱스 위치값으로 특정 항목 가져오기 : df.iloc[행인덱스순서, 열인덱스순서]
#   * 특정 열 가져오기 : df.iloc[:, 열인덱스순서]
#   * 특정 행 가져오기 : df.iloc[행인덱스순서, :]
#   * 특정 항목 가져오기 : df.iloc[행인덱스순서, 열인덱스순서]

# %%
#한 개의 열 자료 가져오기
df.loc[1972, '출생아수']
df.loc[1971:1972, '출생아수':'사망자수']
df.loc[[1971, 1973],['출생아수', '혼인건수']]
# Out:
#          출생아수    혼인건수
# 년도
# 1971  1024773  239457
# 1973   965521  259112

# %%
#여러 개의 열 자료 가져오기
df[['출생아수', '혼인건수']].mean()
# Out:
# 출생아수    635915.901961
# 혼인건수    337232.784314
# dtype: float64

# %%
df.iloc[1:3, 0:2]
# Out:
#          출생아수    사망자수
# 년도
# 1971  1024773  237528
# 1972   952780  210071

# %%
#한 개의 열 자료 데이터프레임으로 가져오기
df.loc[1970:,'출생아수']
# Out:
# 년도
# 1970    1006645
# 1971    1024773
# 1972     952780
# 1973     965521
# 1974     922823
# 1975     874030
# 1976     796331
# 1977     825339
# 1978     750728
# 1979     862669
# 1980     862835
# 1981     867409
# 1982     848312
# 1983     769155
# 1984     674793
# 1985     655489
# 1986     636019
# 1987     623831
# 1988     633092
# 1989     639431
# 1990     649738
# 1991     709275
# 1992     730678
# 1993     715826
# 1994     721185
# 1995     715020
# 1996     691226
# 1997     675394
# 1998     641594
# 1999     620668
# 2000     640089
# 2001     559934
# 2002     496911
# 2003     495036
# 2004     476958
# 2005     438707
# 2006     451759
# 2007     496822
# 2008     465892
# 2009     444849
# 2010     470171
# 2011     471265
# 2012     484550
# 2013     436455
# 2014     435435
# 2015     438420
# 2016     406243
# 2017     357771
# 2018     326822
# 2019     302676
# 2020     272337
# Name: 출생아수, dtype: int64

# %%
#특정 자료 가져오기
df.loc[[2015, 2020],['출생아수', '혼인건수']]
# Out:
#         출생아수    혼인건수
# 년도
# 2015  438420  302828
# 2020  272337  213502

# %% [markdown]
# ## 데이터프레임 정렬
#  - 행 인덱스로 정렬 : df.sort_index(axis=n), n생략 또는 0:행, 1:열
#  - 열 값으로 정렬 : df.sort_values()
#  - 내림차순 옵션 : ascending=False

# %%
# 년도별 내림차순 
df.sort_index(ascending=False).head()
# Out:
#         출생아수    사망자수    혼인건수
# 년도
# 2020  272337  304948  213502
# 2019  302676  295110  239159
# 2018  326822  298820  257622
# 2017  357771  285534  264455
# 2016  406243  280827  281635

# %%
#출생아수가 많은 연도 순으로 나열
df.sort_values('출생아수', ascending=False)
# Out:
#          출생아수    사망자수    혼인건수
# 년도
# 1971  1024773  237528  239457
# 1970  1006645  258589  295137
# 1973   965521  267460  259112
# 1972   952780  210071  244780
# 1974   922823  248807  259604
# 1975   874030  270657  283226
# 1981   867409  237481  406795
# 1980   862835  277284  403031
# 1979   862669  239986  353824
# 1982   848312  245767  387468
# 1977   825339  249254  303156
# 1976   796331  266857  285910
# 1983   769155  254563  412984
# 1978   750728  252298  343013
# 1992   730678  236162  419774
# 1994   721185  242439  393121
# 1993   715826  234257  402593
# 1995   715020  242838  398484
# 1991   709275  242270  416872
# 1996   691226  241149  434911
# 1997   675394  244693  388960
# 1984   674793  236445  385188
# 1985   655489  240418  384686
# 1990   649738  241616  399312
# 1998   641594  245825  373500
# 2000   640089  248740  332090
# 1989   639431  236818  410708
# 1986   636019  239256  390229
# 1988   633092  235779  410129
# 1987   623831  243504  390276
# 1999   620668  247734  360407
# 2001   559934  243813  318407
# 2002   496911  247524  304877
# 2007   496822  246482  343559
# 2003   495036  246463  302503
# 2012   484550  267221  327073
# 2004   476958  246220  308598
# 2011   471265  257396  329087
# 2010   470171  255405  326104
# 2008   465892  246113  327715
# 2006   451759  244162  330634
# 2009   444849  246942  309759
# 2005   438707  245874  314304
# 2015   438420  275895  302828
# 2013   436455  266257  322807
# 2014   435435  267692  305507
# 2016   406243  280827  281635
# 2017   357771  285534  264455
# 2018   326822  298820  257622
# 2019   302676  295110  239159
# 2020   272337  304948  213502

# %%
#혼인건수가 작은 5개년도
df.sort_values('혼인건수').head()
# Out:
#          출생아수    사망자수    혼인건수
# 년도
# 2020   272337  304948  213502
# 2019   302676  295110  239159
# 1971  1024773  237528  239457
# 1972   952780  210071  244780
# 2018   326822  298820  257622

# %% [markdown]
# ## 데이터프레임 새로운 열 생성
# + df['새로운열명'] = 시리즈데이터

# %%
#새로운 열 생성
df['자연증가수'] = df['출생아수']-df['사망자수']

# %%
df.info()
df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1970 to 2020
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   출생아수    51 non-null     int64
#  1   사망자수    51 non-null     int64
#  2   혼인건수    51 non-null     int64
#  3   자연증가수   51 non-null     int64
# dtypes: int64(4)
# memory usage: 4.5 KB
#          출생아수    사망자수    혼인건수   자연증가수
# 년도
# 1970  1006645  258589  295137  748056
# 1971  1024773  237528  239457  787245

# %%
#전년도 출생아수열 만들기
lt = list(df['출생아수'])
lt.insert(0, 0)
lt.pop()
df['전년도 출생아수'] = lt
df.head()
# Out:
#          출생아수    사망자수    혼인건수   자연증가수  전년도 출생아수
# 년도
# 1970  1006645  258589  295137  748056         0
# 1971  1024773  237528  239457  787245   1006645
# 1972   952780  210071  244780  742709   1024773
# 1973   965521  267460  259112  698061    952780
# 1974   922823  248807  259604  674016    965521

# %%
#전년도 대비 출생아수
df['전년도 대비 출생아수'] = df['출생아수'] - df['전년도 출생아수']
df.head()
# Out:
#          출생아수    사망자수    혼인건수   자연증가수  전년도 출생아수  전년도 대비 출생아수
# 년도
# 1970  1006645  258589  295137  748056         0      1006645
# 1971  1024773  237528  239457  787245   1006645        18128
# 1972   952780  210071  244780  742709   1024773       -71993
# 1973   965521  267460  259112  698061    952780        12741
# 1974   922823  248807  259604  674016    965521       -42698

# %% [markdown]
# ## **조건에 맞는 자료 추출**
#
#
# ---
# + df[조건식]
#   + 시리즈.isin([리스트])
#   + and 연산 : &
#   + or 연산 : |
#   + and 연산이나 or연산인 경우는 반드시 ()로 묶어서 사용

# %%
#전년도 대비 출생아수가 감소한 년도 
df[df['전년도 대비 출생아수'] < 0]
# Out:
#         출생아수    사망자수    혼인건수   자연증가수  전년도 출생아수  전년도 대비 출생아수
# 년도
# 1972  952780  210071  244780  742709   1024773       -71993
# 1974  922823  248807  259604  674016    965521       -42698
# 1975  874030  270657  283226  603373    922823       -48793
# 1976  796331  266857  285910  529474    874030       -77699
# 1978  750728  252298  343013  498430    825339       -74611
# 1982  848312  245767  387468  602545    867409       -19097
# 1983  769155  254563  412984  514592    848312       -79157
# 1984  674793  236445  385188  438348    769155       -94362
# 1985  655489  240418  384686  415071    674793       -19304
# 1986  636019  239256  390229  396763    655489       -19470
# 1987  623831  243504  390276  380327    636019       -12188
# 1993  715826  234257  402593  481569    730678       -14852
# 1995  715020  242838  398484  472182    721185        -6165
# 1996  691226  241149  434911  450077    715020       -23794
# 1997  675394  244693  388960  430701    691226       -15832
# 1998  641594  245825  373500  395769    675394       -33800
# 1999  620668  247734  360407  372934    641594       -20926
# 2001  559934  243813  318407  316121    640089       -80155
# 2002  496911  247524  304877  249387    559934       -63023
# 2003  495036  246463  302503  248573    496911        -1875
# 2004  476958  246220  308598  230738    495036       -18078
# 2005  438707  245874  314304  192833    476958       -38251
# 2008  465892  246113  327715  219779    496822       -30930
# 2009  444849  246942  309759  197907    465892       -21043
# 2013  436455  266257  322807  170198    484550       -48095
# 2014  435435  267692  305507  167743    436455        -1020
# 2016  406243  280827  281635  125416    438420       -32177
# 2017  357771  285534  264455   72237    406243       -48472
# 2018  326822  298820  257622   28002    357771       -30949
# 2019  302676  295110  239159    7566    326822       -24146
# 2020  272337  304948  213502  -32611    302676       -30339

# %%
#전년대비 증가 감소 구분 
lt = ['증가' if item>=0 else '감소' for item in list(df['전년도 대비 출생아수'])]
df['증감'] = lt
df.head()
# Out:
#          출생아수    사망자수    혼인건수   자연증가수  전년도 출생아수  전년도 대비 출생아수  증감
# 년도
# 1970  1006645  258589  295137  748056         0      1006645  증가
# 1971  1024773  237528  239457  787245   1006645        18128  증가
# 1972   952780  210071  244780  742709   1024773       -71993  감소
# 1973   965521  267460  259112  698061    952780        12741  증가
# 1974   922823  248807  259604  674016    965521       -42698  감소

# %% [markdown]
# ## 외부 파일로 저장
# + csv 쓰기
# ```
# df.to_csv(‘파일명‘, index=False)
# ```
#
# + 엑셀 쓰기
# ```
# df.to_excel(‘파일명‘)
# ```

# %%
df.to_csv('/content/drive/MyDrive/datathon/class/data/인구분석_출생사망_결과', index=False)
